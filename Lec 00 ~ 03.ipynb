# %% [markdown]
# <a href="https://colab.research.google.com/github/nana-hyun/Machine-Learning/blob/master/Lec%2000%20~%2003.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML
#
# * Supervised learning
#     * learning with labeled examples - training set
#     * Image labeling, Email spam
#
# * Unsupervised learning
#     * un-labeled data ; clustering
#
# **Training data set**
#
# supervised learning에서 ML 훈련시킬 때 사용하는 dataset
#
# * regression : predicting final exam score
#
# * binary classification : pass/non-pass
#
# * multi-label classification : letter grade(A, B, C and F)

# %% [markdown]
# # Tensorflow
#
# * python 사용
#
# node에서 수학적 연산을 하고, edge를 통해 data array들이 node 사이를 이동할 수 있다.
#
# * data arrays : tensors

# %%
import tensorflow as tf

# %%
hello = tf.constant("Hello, Tensorflow!")

# %% [markdown]
# ## Session

# %%
#  import tensorflow.compat.v1 as tf
#  tf.compat.v1.disable_eager_execution() or tf.disable_v2_behavior()  tensorflow v2에서는 더이상 session을 지원하지 않음

sess = tf.Session()

print(sess.run(hello))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12908\2201312856.py in <module>
#       2 #  tf.compat.v1.disable_eager_execution()   tensorflow v2에서는 더이상 session을 지원하지 않음
#       3
# ----> 4 sess = tf.Session()
#       5
#       6 a = tf.placeholder(tf.float32)
#
# AttributeError: module 'tensorflow' has no attribute 'Session'

# %%
tf.print(hello)
# Out:
# Hello, Tensorflow!

# %%
print(hello)
# Out:
# tf.Tensor(b'Hello, Tensorflow!', shape=(), dtype=string)

# %%
import tensorflow.compat.v1 as tf
tf.compat.v1.disable_eager_execution()

# %%
node1 = tf.constant(17.5)
node2 = tf.constant(5.0)

# %%
node3 = tf.add(node1, node2)

# %%
print(node3)
# Out:
# Tensor("Add_2:0", shape=(), dtype=float32)

# %%
sess = tf.Session()
sess.run(node3)
# Out:
# 22.5

# %% [markdown]
# ## Placeholder

# %%
a = tf.placeholder(tf.float32)   # tensorflow v2에서는 더이상 placeholder를 지원하지 않음
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12908\716387603.py in <module>
# ----> 1 a = tf.placeholder(tf.float32)
#
# AttributeError: module 'tensorflow' has no attribute 'placeholder'

# %%
@tf.function

def adder(a, b):
    return a + b

A = tf.constant(1)
B = tf.constant(2)
print(adder(A, B))

C = tf.constant([1, 3])
D = tf.constant([2, 4])
print(adder(C, D))
# Out:
# tf.Tensor(3, shape=(), dtype=int32)
# tf.Tensor([3 7], shape=(2,), dtype=int32)

# %%
import tensorflow.compat.v1 as tf
tf.compat.v1.disable_eager_execution()

# %%
a = tf.placeholder(tf.float32)
b = tf.placeholder(tf.float32)
adder_node = a + b
sess = tf.Session()
print(sess.run(adder_node, feed_dict={a: 3, b: 4.5}))
print(sess.run(adder_node, feed_dict={a: [1, 3], b: [2, 4]}))
# Out:
# 7.5
# [3. 7.]

# %% [markdown]
# # Linear Regression
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# 데이터들을 선형적으로 나타낼 수 있다.
#
# ![image.png](data:image/png;base64,...)
#
# H(x) = Wx + b
#
# 로 나타낼 수 있으며, 어떤 Hypothesis function이 dataset을 가장 잘 설명하는지 찾아야 한다.
#
# 이를 위해
#
# ![image.png](data:image/png;base64,...)
#
# 원래의 data들과 hypothesis의 차이를 이용해 가장 적합한 hypothesis를 구한다.
#
# ![image.png](data:image/png;base64,...)
#
# 제곱을 한 이유는 음의 값이 나오지 않기 때문이기도 하고, 에러가 큰 것에 대해 더 큰 패널티를 부여할 수 있기 때문이다.
#
# ![image.png](data:image/png;base64,...)
#
# 이렇게 각각의 에러의 합의 평균을 구한 것을 cost function (loss function)이라고 한다.
#
# ![image.png](data:image/png;base64,...)
#
# 우리의 목표는 이러한 cost를 최소화하여 가장 적합한 hypothesis를 찾는 것이다.
#
# ![image.png](data:image/png;base64,...)
